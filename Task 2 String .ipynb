# %%
Section 1: String 

Mask a credit card number (show only the last 4 digits).

 Input: "1234567812345678"

 Output: "************5678"


Extract the domain name from an email address.

 Input: "Ved.M@company.com"

 Output: "company.com"


Convert a sentence into title case (capitalize the first letter of each word).

 Input: "learning python is fun and powerful"

 Output: "Learning Python Is Fun And Powerful"


Check if a given sentence is a palindrome.

 Input: "A man a plan a canal Panama"

 Output: True



Replace all occurrences of a word "Python" with "Data Science" except the first one.

 Input: "Python is great. Python is fun. Python is powerful."

 Output: "Python is great. Data Science is fun. Data Science is powerful."


Convert a file path to a URL format.

 Input: "C:\Users\Ved\Documents\file.txt"

 Output: "C:/Users/Ved/Documents/file.txt"


Extract the first name and last name from a full name.

 Input: "Ved Kumar MT"

 Output: "First Name: Ved, Last Name: MT"


Find the position of the first and last occurrence of a word “Python”  in a sentence.

 Input: "I love Python because Python is powerful and Python is fun."

 Output: "First: 7, Last: 41"


Perform various string operations on a given text.

 Input: "$python is fun, python is easy, but python is tough when you don't practice it revise it@”


How many characters are present in the above string?
Split the string using commas (,)
Count the frequency of "python"
Count the frequency of "is"
Check the results of +, -, *, /, // operations on 3 and 4
Replace "when " with "if and only if"



Perform different operations on a given sentence.
Input: " Hello World I am learning Python in Innomatics "
Find the total number of characters in the string.
Extract only the word "Python" from the string.
Trim the white spaces from both sides and find the new character count.
Convert the entire string to uppercase.
Find the index position of "World" in the string.
Split the string using whitespace, store it in a variable, and print the data type of the resulting variable.

Perform various string operations on a given sentence.
Input: "Data Science is an evolving field with endless opportunities."
Access the first character of the string using indexing.
Access the last character using negative indexing.
Extract the word "Science" using forward slicing.
Extract the word "opportunities" using reverse slicing.
Print the string in reverse order using slicing.

# %% [markdown]
# ### Section 1: String

# %% [markdown]
# ### 1 Mask a credit card number (show only the last 4 digits).

# %% [markdown]
#  Input: "1234567812345678"
#
#  Output: "************5678"

# %%
card_number = "1234567812345678"

# %%
masked_number = "*"*(len(card_number)-4)+card_number[-4:]
masked_number
# Out:
# '************5678'

# %% [markdown]
#  ### 2 Extract the domain name from an email address.

# %% [markdown]
# Input: "Ved.M@company.com"
#
# Output: "company.com"

# %%
email =  "Ved.M@company.com"

# %%
email = ("Ved.M@company.com")
email.replace ("Ved.M@company.com","company.com")
# Out:
# 'company.com'

# %% [markdown]
# ### 3 Convert a sentence into title case (capitalize the first letter of each word).

# %% [markdown]
# Input: "learning python is fun and powerful"
#
# Output: "Learning Python Is Fun And Powerful"

# %%
x= "learning python is fun and powerful"
x
# Out:
# 'learning python is fun and powerful'

# %%
x.title ()
# Out:
# 'Learning Python Is Fun And Powerful'

# %% [markdown]
# ### 4 Check if a given sentence is a palindrome.

# %% [markdown]
#  Input: "A man a plan a canal Panama"
#
#  Output: True

# %%
sentence = "A man a plan a canal Panama"

# %%
sentence = sentence.lower()
sentence
# Out:
# 'a man a plan a canal panama'

# %%
sentence = sentence.replace(" ", "")
sentence
# Out:
# 'amanaplanacanalpanama'

# %%
sentence==sentence[::-1]
# Out:
# True

# %% [markdown]
# ### 5 Replace all occurrences of a word "Python" with "Data Science" except the first one.

# %% [markdown]
# Input: "Python is great. Python is fun. Python is powerful."
#
#  Output: "Python is great. Data Science is fun. Data Science is powerful."

# %%
x1 =  ("Python is great. Python is fun. Python is powerful.")
x1
# Out:
# 'Python is great. Python is fun. Python is powerful.'

# %%
x1 = x1.replace ("Python","Data Science")
print (x1)
# Out:
# Data Science is great. Data Science is fun. Data Science is powerful.

# %%
x1 = x1.replace("Data Science is great","Python is great") 
print(x1)
# Out:
# Python is great. Data Science is fun. Data Science is powerful.

# %% [markdown]
# ### 6 Convert a file path to a URL format.

# %% [markdown]
#  Input: "C:\Users\Ved\Documents\file.txt"
#
#  Output: "C:/Users/Ved/Documents/file.txt"

# %%
file_path = r"C:\Users\Ved\Documents\file.txt"

# %%
url_format =" C:/Users/Ved/Documents/file.txt "
print(f'"{url_format}"')
# Out:
# " C:/Users/Ved/Documents/file.txt "

# %% [markdown]
# ### 7 Extract the first name and last name from a full name.

# %% [markdown]
# Input: "Ved Kumar MT"
#
# Output: "First Name: Ved, Last Name: MT"

# %%
name = input ('Enter your first name:')
# Out:
# Enter your first name: Ved

# %%
name = input ('Enter your second name : ')
# Out:
# Enter your second name :  MT

# %% [markdown]
# ### 8 Find the position of the first and last occurrence of a word “Python”  in a sentence.

# %% [markdown]
# Input: "I love Python because Python is powerful and Python is fun."
#
# Output: "First: 7, Last: 41"

# %%
var=("I love Python because Python is powerful and Python is fun.")
var
# Out:
# 'I love Python because Python is powerful and Python is fun.'

# %%
var.find ("Python")
# Out:
# 7

# %%
first_occurrence = var.find("Python")  
last_occurrence = var.rfind("Python")

# %%
print(f"First: {first_occurrence}, Last: {last_occurrence}")
# Out:
# First: 7, Last: 45

# %% [markdown]
# ### 9 Perform various string operations on a given text.

# %% [raw]
# Input: "$python is fun, python is easy, but python is tough when you don't practice it revise it@”
#
#
# *How many characters are present in the above string?
# *Split the string using commas (,)
# *Count the frequency of "python"
# *Count the frequency of "is"
# *Check the results of +, -, *, /, // operations on 3 and 4
# *Replace "when " with "if and only if"

# %% [markdown]
# ## How many characters are present in the above string?

# %%
text = "$python is fun, python is easy, but python is tough when you don't practice it revise it@"
character_count = len(text)
print("Character Count:", character_count)
# Out:
# Character Count: 89

# %% [markdown]
# ## Split the string using commas (,)

# %%
split_text = text.split(",")
print("Split Text:", split_text)
# Out:
# Split Text: ['$python is fun', ' python is easy', " but python is tough when you don't practice it revise it@"]

# %% [markdown]
# ## Count the frequency of "python"

# %%
text.count("python")
# Out:
# 3

# %% [markdown]
# ## Count the frequency of "is"

# %%
text.count("is")
# Out:
# 4

# %% [markdown]
# ## Check the results of +, -, *, /, // operations on 3 and 4

# %%
a,b = 3,4

print("3 + 4 =", a + b)
print("3 - 4 =", a - b)
print("3 * 4 =", a * b)
print("3 / 4 =", a / b)
print("3 // 4 =", a // b)
# Out:
# 3 + 4 = 7
# 3 - 4 = -1
# 3 * 4 = 12
# 3 / 4 = 0.75
# 3 // 4 = 0

# %% [markdown]
# ## Replace "when " with "if and only if"

# %%
updated_text = text.replace ("when","if and only if")
updated_text
# Out:
# "$python is fun, python is easy, but python is tough if and only if you don't practice it revise it@"

# %% [markdown]
# ### 10 Perform different operations on a given sentence.

# %% [markdown]
# Input: " Hello World I am learning Python in Innomatics "

# %% [raw]
# Find the total number of characters in the string.
# Extract only the word "Python" from the string.
# Trim the white spaces from both sides and find the new character count.
# Convert the entire string to uppercase.
# Find the index position of "World" in the string.
# Split the string using whitespace, store it in a variable, and print the data type of the resulting variable.

# %% [markdown]
#  ## Find the total number of characters in the string

# %%
text =  " Hello World I am learning Python in Innomatics "
text
# Out:
# ' Hello World I am learning Python in Innomatics '

# %%
character_count = len(text)
print('total characters:',character_count)
# Out:
# total characters: 48

# %% [markdown]
# ## Extract only the word "Python" from the string.

# %%
word_python = text.split()[7]  
print("Extracted Word:", word_python)
# Out:
# Extracted Word: python

# %% [markdown]
# ## Trim the white spaces from both sides and find the new character count.

# %%
 text =  " Hello World I am learning Python in Innomatics "
 text
# Out:
# ' Hello World I am learning Python in Innomatics '

# %%
text = text.strip()
text
# Out:
# 'Hello World I am learning Python in Innomatics'

# %%
character_count = len (text)
print(character_count)
# Out:
# 46

# %% [markdown]
# ## Convert the entire string to uppercase.

# %%
text = (" Hello World I am learning Python in Innomatics ")
text
# Out:
# ' Hello World I am learning Python in Innomatics '

# %%
text.upper()
# Out:
# ' HELLO WORLD I AM LEARNING PYTHON IN INNOMATICS '

# %% [markdown]
# ## Find the index position of "World" in the string.

# %%
text.find ("World")
# Out:
# 7

# %% [markdown]
# ## Split the string using whitespace, store it in a variable, and print the data type of the resulting variable.

# %%
split_text = text.split()
print(split_text)
# Out:
# ['Hello', 'World', 'I', 'am', 'learning', 'Python', 'in', 'Innomatics']

# %%
print("Data Type:", type(split_text))
# Out:
# Data Type: <class 'list'>

# %% [markdown]
# ### 11 Perform various string operations on a given sentence.

# %% [markdown]
#  Input: "Data Science is an evolving field with endless opportunities."

# %% [markdown]
# *Access the first character of the string using indexing.
# *Access the last character using negative indexing.
# *Extract the word "Science" using forward slicing.
# *Extract the word "opportunities" using reverse slicing.
# *Print the string in reverse order using slicing.

# %%
var =("Data Science is an evolving field with endless opportunities.")

# %% [markdown]
# ## Access the first character of the string using indexing.

# %%
first_character = var [0]
print(first_character)
# Out:
# D

# %% [markdown]
# ## Access the last character using negative indexing.

# %%
last_character = var [-1]
print(last_character)
# Out:
# .

# %% [markdown]
# ## Extract the word "Science" using forward slicing.

# %%
var [5:12]
# Out:
# 'Science'

# %% [markdown]
# ## Extract the word "opportunities" using reverse slicing.

# %%
var[-14:]
# Out:
# 'opportunities.'

# %% [markdown]
# ## Print the string in reverse order using slicing.

# %%
var [::-1]
# Out:
# '.seitinutroppo sseldne htiw dleif gnivlove na si ecneicS ataD'
